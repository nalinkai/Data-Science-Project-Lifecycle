# %% [markdown]
# <a href="https://colab.research.google.com/github/nalinkai/Data-Science-Project-Lifecycle/blob/Dev/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Data Science Life Cycle Coursework/Hotel-A-train.csv')

# %% [markdown]
# Handle Duplicate Records

# %%
# Keep the first occurrence and drop others, keeping one row per Reservation-id
df = df.drop_duplicates(subset='Reservation-id', keep='first')

# %% [markdown]
# Standardize Categorical Variables

# %%
# Apply to all object columns, or specifically to the problem ones
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.lower()

# %% [markdown]
# Convert Date Columns to Datetime

# %%
date_cols = ['Expected_checkin', 'Expected_checkout', 'Booking_date']
for col in date_cols:
    df[col] = pd.to_datetime(df[col])

# %%
df.head()
# Out:
#    Reservation-id Gender  Age         Ethnicity Educational_Level  \
# 0        39428300      f   40            latino              grad
# 1        77491756      f   49            latino        mid-school
# 2        73747291      f   42         caucasian              grad
# 3        67301739      m   25  african american           college
# 4        77222321      f   62            latino       high-school
#
#         Income Country_region      Hotel_Type Expected_checkin  \
# 0         <25k          north      city hotel       2015-07-01
# 1  50k -- 100k           east      city hotel       2015-07-01
# 2         <25k           east      city hotel       2015-07-02
# 3        >100k          south  airport hotels       2015-07-02
# 4    25k --50k           east          resort       2015-07-03
#
#   Expected_checkout  ... Meal_Type  Visted_Previously  Previous_Cancellations  \
# 0        2015-07-02  ...        bb                 no                      no
# ...
